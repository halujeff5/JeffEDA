# %%
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
html_page = requests.get('https://en.wikipedia.org/wiki/2010s_in_film') # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing
import pandas as pd

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Film_industry#Statistics')
df[2] #used to make graph 1
# Out:
#     Rank         Country  Box office revenue (billion US$)       Year  \
# 0    NaN           World                             41.70    2018[1]
# 1    1.0   United States                             11.08  2018[133]
# 2    2.0           China                              9.15  2018[133]
# 3    3.0           India                              2.44  2018[135]
# 4    4.0           Japan                              2.39  2019[130]
# 5    5.0  United Kingdom                              1.72  2018[133]
# 6    6.0     South Korea                              1.60  2017[136]
# 7    7.0          France                              1.50  2018[133]
# 8    8.0         Germany                              1.11  2018[133]
# 9    9.0          Russia                              1.00  2017[136]
# 10  10.0       Australia                              0.95  2018[133]
# 11  11.0          Brazil                              0.90  2017[136]
# ...

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Film_industry#Statistics')
df[1]
# Out:
#     Rank         Country  Films       Year
# 0      1           India   1813    2018[4]
# 1      2         Nigeria    997       2011
# 2      3           China    874       2017
# 3      4           Japan    689  2019[130]
# 4      5   United States    660       2017
# 5      6     South Korea    339       2016
# 6      7          France    300       2017
# 7      8  United Kingdom    285       2017
# 8      9           Spain    241       2017
# 9     10         Germany    233       2017
# 10    11       Argentina    220       2015
# 11    12          Mexico    176  2017[131]
# 12    13           Italy    173       2017
# 13    14          Brazil    160       2017
# 14    15          Turkey    148       2017

# %%
url = 'https://www.the-numbers.com/movie/budgets'
html_page = requests.get(url) 
soup = BeautifulSoup(html_page.content, 'html.parser') #this data was not used.

for record in soup.findAll('td'):
    print(record.text)
# Out:
# 1
# Apr 26, 2019
# Avengers: Endgame
# $400,000,000
# $858,373,000
# $2,797,800,564
# 2
# May 20, 2011
# Pirates of the Caribbean: On Stranger Tides
# $379,000,000
# $241,063,875
# $1,045,663,875
# 3
# May 1, 2015
# Avengers: Age of Ultron
# $365,000,000
# $459,005,868
# $1,403,013,963
# 4
# Dec 18, 2015
# Star Wars Ep. VII: The Force Awakens
# $306,000,000
# $936,662,225
# $2,068,223,624
# 5
# May 24, 2007
# Pirates of the Caribbean: At Worldâs End
# $300,000,000
# $309,420,425
# $963,420,425
# 6
# Nov 6, 2015
# Spectre
# $300,000,000
# $200,074,175
# $879,620,923
# 7
# Apr 27, 2018
# Avengers: Infinity War
# $300,000,000
# $678,815,482
# $2,048,359,754
# 8
# Nov 17, 2017
# Justice League
# $300,000,000
# $229,024,295
# $655,945,209
# 9
# Dec 20, 2019
# Star Wars: The Rise of Skywalker
# $275,000,000
# $515,202,542
# $1,074,141,030
# 10
# May 25, 2018
# Solo: A Star Wars Story
# $275,000,000
# $213,767,512
# $393,151,347
# 11
# Mar 9, 2012
# John Carter
# $263,700,000
# ...

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1990')
#not used

# %%
df1=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1991')
#not used

# %%
df2=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1992')
#not used

# %%
df3=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1993')
#not used

# %%
df4=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1994')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1995')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1996')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1997')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1998')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_1999')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2000')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2001')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2002')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2003')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2004')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2005')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2006')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2007')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2008')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2009')
#not used

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_horror_films_of_2010')
#not used

# %%
import requests
import json
import numpy as np
import pandas as pd
